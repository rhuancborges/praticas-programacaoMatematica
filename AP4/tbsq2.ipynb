# %% [markdown]
# $$
# \begin{array}{c|c c c c c|c}
# \hline
# \hline
#  & x_1 & x_2 & s_1 & s_2 & s_3 & \\
# \hline
#  & 0 & 0 & \frac{1}{5} & 0 & \frac{18}{5} & \frac{67}{5} \\
# x_1 & 1 & 0 & 0 & 0 & 1 & 3 \\
# x_2 & 0 & 1 & -\frac{1}{5} & 0 & \frac{7}{5} & \frac{8}{5} \\
# s_2 & 0 & 0 & \frac{2}{5} & 1 & -\frac{29}{5} & \frac{24}{5} \\
# \hline
# \end{array}
# $$
#
# - Inserindo $3x_1 - 2x_2 + s_4 = 5$:
#
# $$
# \begin{array}{c|c c c c c c|c}
# \hline
# \hline
#  & x_1 & x_2 & s_1 & s_2 & s_3 & s_4 &  \\
# \hline
#  & 0 & 0 & \frac{1}{5} & 0 & \frac{18}{5} & 0 & \frac{67}{5} \\
# x_1 & 1 & 0 & 0 & 0 & 1 & 0 & 3 \\
# x_2 & 0 & 1 & -\frac{1}{5} & 0 & \frac{7}{5} & 0 & \frac{8}{5} \\
# s_2 & 0 & 0 & \frac{2}{5} & 1 & -\frac{29}{5} & 0 & \frac{24}{5} \\
# s_4 & 3 & -2 & 0 & 0 & 0 & 1 & 5 \\
# \hline
# \end{array}
# $$
#
# - Aplicando pivoteamento $L_5' = L_5 - 3L_2$:
#
# $$
# \begin{array}{c|c c c c c c|c}
# \hline
# \hline
#  & x_1 & x_2 & s_1 & s_2 & s_3 & s_4 &  \\
# \hline
#  & 0 & 0 & \frac{1}{5} & 0 & \frac{18}{5} & 0 & \frac{67}{5} \\
# x_1 & 1 & 0 & 0 & 0 & 1 & 0 & 3 \\
# x_2 & 0 & 1 & -\frac{1}{5} & 0 & \frac{7}{5} & 0 & \frac{8}{5} \\
# s_2 & 0 & 0 & \frac{2}{5} & 1 & -\frac{29}{5} & 0 & \frac{24}{5} \\
# s_4 & 0 & -2 & 0 & 0 & -3 & 1 & -4 \\
# \hline
# \end{array}
# $$
#
# - Aplicando pivoteamento $L_5' = L_5 + 2L_3$:
#
# $$
# \begin{array}{c|c c c c c c|c}
# \hline
# \hline
#  & x_1 & x_2 & s_1 & s_2 & s_3 & s_4 &  \\
# \hline
#  & 0 & 0 & \frac{1}{5} & 0 & \frac{18}{5} & 0 & \frac{67}{5} \\
# x_1 & 1 & 0 & 0 & 0 & 1 & 0 & 3 \\
# x_2 & 0 & 1 & -\frac{1}{5} & 0 & \frac{7}{5} & 0 & \frac{8}{5} \\
# s_2 & 0 & 0 & \frac{2}{5} & 1 & -\frac{29}{5} & 0 & \frac{24}{5} \\
# s_4 & 0 & 0 & -\frac{2}{5} & 0 & -\frac{1}{5} & 1 & \mathbf{\textcolor{red}{-\frac{4}{5}}} \\
# \hline
# \end{array}
# $$
